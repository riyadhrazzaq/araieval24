# %% [markdown]
# # [Task 2B: Multimodal Propagandistic Memes Classification](https://araieval.gitlab.io/task2/) at [ArabicNLP 2024](https://arabicnlp2024.sigarab.org/) @ACL 2024
#
# @Author: Md. Arid Hasan
#
# Given a meme (text overlayed image), the task is to detect whether the content is propagandistic.

# %% [markdown]
# ### Downloading dataset from github

# %%
# !wget https://gitlab.com/araieval/araieval_arabicnlp24/-/raw/main/task2/data/arabic_memes_propaganda_araieval_24_train.json
# !wget https://gitlab.com/araieval/araieval_arabicnlp24/-/raw/main/task2/data/arabic_memes_propaganda_araieval_24_dev.json
# !wget https://gitlab.com/araieval/araieval_arabicnlp24/-/raw/main/task2/data/arabic_memes_araieval_24_train_dev.tar.gz
# Out:
# --2024-03-22 06:07:23--  https://gitlab.com/araieval/araieval_arabicnlp24/-/raw/main/task2/data/arabic_memes_propaganda_araieval_24_train.json
# Resolving gitlab.com (gitlab.com)... 172.65.251.78, 2606:4700:90:0:f22e:fbec:5bed:a9b9
# Connecting to gitlab.com (gitlab.com)|172.65.251.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1027033 (1003K) [text/plain]
# Saving to: ‘arabic_memes_propaganda_araieval_24_train.json’
#
# arabic_memes_propag 100%[===================>]   1003K  --.-KB/s    in 0.06s
#
# 2024-03-22 06:07:23 (16.3 MB/s) - ‘arabic_memes_propaganda_araieval_24_train.json’ saved [1027033/1027033]
#
# --2024-03-22 06:07:24--  https://gitlab.com/araieval/araieval_arabicnlp24/-/raw/main/task2/data/arabic_memes_propaganda_araieval_24_dev.json
# Resolving gitlab.com (gitlab.com)... 172.65.251.78, 2606:4700:90:0:f22e:fbec:5bed:a9b9
# Connecting to gitlab.com (gitlab.com)|172.65.251.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 150732 (147K) [text/plain]
# Saving to: ‘arabic_memes_propaganda_araieval_24_dev.json’
#
# arabic_memes_propag 100%[===================>] 147.20K  --.-KB/s    in 0.02s
#
# 2024-03-22 06:07:24 (6.21 MB/s) - ‘arabic_memes_propaganda_araieval_24_dev.json’ saved [150732/150732]
#
# --2024-03-22 06:07:24--  https://gitlab.com/araieval/araieval_arabicnlp24/-/raw/main/task2/data/arabic_memes_araieval_24_train_dev.tar.gz
# Resolving gitlab.com (gitlab.com)... 172.65.251.78, 2606:4700:90:0:f22e:fbec:5bed:a9b9
# Connecting to gitlab.com (gitlab.com)|172.65.251.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 173093194 (165M) [application/gzip]
# Saving to: ‘arabic_memes_araieval_24_train_dev.tar.gz’
#
# arabic_memes_araiev 100%[===================>] 165.07M  86.6MB/s    in 1.9s
#
# 2024-03-22 06:07:26 (86.6 MB/s) - ‘arabic_memes_araieval_24_train_dev.tar.gz’ saved [173093194/173093194]

# %% [markdown]
# #### Extract images

# %%
# !tar -xvzf arabic_memes_araieval_24_train_dev.tar.gz
# Out:
# data/
# data/images/
# data/arabic_memes_fb_insta_pinterest/
# data/fb_memes/
# data/fb_memes/arabic_memes_officiel/
# data/fb_memes/ArabMemes/
# data/fb_memes/ArabianMemez/
# data/fb_memes/ArabianMemez/278858577_1339875849853306_5941896038764612993_n.jpg
# data/fb_memes/ArabianMemez/36526999_401564060351161_8715172479686934528_n.jpg
# data/fb_memes/ArabianMemez/91360473_824623961378500_3826031840225918976_n.jpg
# data/fb_memes/ArabianMemez/118206419_928062101034685_4055080010757517077_n.jpg
# data/fb_memes/ArabianMemez/34157766_378837719290462_338446270488117248_n.jpg
# data/fb_memes/ArabianMemez/339604724_240280365162274_8475128203519352213_n.jpg
# data/fb_memes/ArabianMemez/90937780_821464438361119_600839849963945984_n.jpg
# data/fb_memes/ArabianMemez/119461671_946759942498234_4488099900544799148_n.jpg
# data/fb_memes/ArabianMemez/325596730_3561165430866879_9207462464562099758_n.jpg
# data/fb_memes/ArabianMemez/272646015_1281287772378781_3628850103179921723_n.jpg
# data/fb_memes/ArabianMemez/322699002_707502734236766_7415078832308873698_n.jpg
# data/fb_memes/ArabianMemez/321803431_1871895753171418_1805021138788232497_n.jpg
# data/fb_memes/ArabianMemez/118518502_934286637078898_3512815232799102293_n.jpg
# data/fb_memes/ArabianMemez/58443613_585201411987424_9089036794254589952_n.jpg
# data/fb_memes/ArabianMemez/72582823_691670648007166_5867231707828060160_n.jpg
# data/fb_memes/ArabianMemez/34863357_381546472352920_242077190164840448_n.jpg
# data/fb_memes/ArabianMemez/130412454_1016457005528527_2600990077279845805_n.jpg
# data/fb_memes/ArabianMemez/44511775_481340015706898_2882644300884082688_n.jpg
# data/fb_memes/ArabianMemez/80640175_754597748381122_5429072531703201792_n.jpg
# data/fb_memes/ArabianMemez/76177905_699223283918569_445235925019000832_n.jpg
# data/fb_memes/ArabianMemez/90180497_819960631844833_1418183422156734464_n.jpg
# data/fb_memes/ArabianMemez/28783113_341182669722634_981240018129387520_n.jpg
# data/fb_memes/ArabianMemez/109980169_903483353492560_2396013206707385683_n.jpg
# data/fb_memes/ArabianMemez/42303742_467871173720449_5277532165511315456_n.jpg
# data/fb_memes/ArabianMemez/324024715_1175987086622599_3807521269437894508_n.jpg
# data/fb_memes/ArabianMemez/144198458_1051405025367058_982236224103892320_n.jpg
# data/fb_memes/ArabianMemez/338202781_873311837303553_7354440452159913425_n.jpg
# data/fb_memes/ArabianMemez/44234899_479222829251950_5113307459519250432_n.jpg
# data/fb_memes/ArabianMemez/100919827_864039387436957_922219058584092672_n.jpg
# data/fb_memes/ArabianMemez/44396171_480348765806023_8386393523452116992_n.jpg
# data/fb_memes/ArabianMemez/271263167_1269051893602369_2788597173398969409_n.jpg
# data/fb_memes/ArabianMemez/84149610_784300672077496_6652928242997002240_n.jpg
# data/fb_memes/ArabianMemez/36825308_407418829765684_5180899687728676864_n.jpg
# data/fb_memes/ArabianMemez/43677210_476656509508582_7749137577793290240_n.jpg
# data/fb_memes/ArabianMemez/32940207_372828993224668_1843269327717924864_n.jpg
# data/fb_memes/ArabianMemez/56985335_575447052962860_7590020949420802048_n.jpg
# data/fb_memes/ArabianMemez/275137990_1308798969627661_2215016878697740711_n.jpg
# data/fb_memes/ArabianMemez/42161672_466943327146567_3481415033173311488_n.jpg
# data/fb_memes/ArabMemes/ArabMemes17553691_1131078530353578_850620112447118178_n.jpg
# data/fb_memes/ArabMemes/ArabMemes20914169_1275456309249132_1520437595841401664_n.jpg
# data/fb_memes/ArabMemes/ArabMemes11921792_734078550053580_1183778386623181999_n.jpg
# data/fb_memes/ArabMemes/ArabMemes57533101_2077626195698802_4429767120917626880_n.jpg
# data/fb_memes/ArabMemes/ArabMemes14141814_929724923822274_4007553745679387017_n.jpg
# data/fb_memes/ArabMemes/ArabMemes13339542_875416525919781_9030065331177653787_n.jpg
# data/fb_memes/ArabMemes/ArabMemes12250124_765667453561356_2007529660127448873_n.jpg
# data/fb_memes/ArabMemes/ArabMemes55680212_2038335266294562_1418280187769913344_n.jpg
# data/fb_memes/ArabMemes/ArabMemes14316747_941441099317323_7459374405152144336_n.jpg
# data/fb_memes/ArabMemes/ArabMemes11796370_721534694641299_6387696286915723344_n.jpg
# data/fb_memes/arabic_memes_officiel/117393094_138507184591642_6561610759114374987_n.jpg
# data/fb_memes/arabic_memes_officiel/117562606_137916544650706_3335867445901656839_n.jpg
# data/fb_memes/arabic_memes_officiel/106478336_106560027786358_5582631969684395853_n.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/
# data/arabic_memes_fb_insta_pinterest/Facebook/
# data/arabic_memes_fb_insta_pinterest/Instagram/
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/de7ktna/
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/comiicsatk/
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/8yerjaw/
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-04-18_17-46-23_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-03-04_18-12-11_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-02-09_20-34-25_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-01-31_11-51-54_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2019-10-03_17-27-01_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-06-13_09-44-33_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-01-30_20-07-37_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-08-09_13-21-58_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-03-05_21-04-37_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-03-19_20-36-55_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-01-10_21-34-18_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-11-22_13-27-46_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-10-12_14-56-34_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-09-23_15-50-44_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-04-25_19-40-32_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-07-11_15-00-05_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-02-26_20-19-58_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-02-23_10-03-55_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-06-21_11-02-23_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-08-30_13-23-03_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-11-17_16-39-42_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-01-27_19-44-53_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-08-16_22-20-15_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-01-11_11-50-15_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-01-14_18-22-10_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-11-25_10-59-41_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-06-17_14-44-38_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-12-12_13-35-58_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-06-16_15-37-55_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-11-11_12-55-32_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-01-13_13-51-55_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-02-23_17-43-40_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-06-04_12-20-19_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2019-12-01_15-11-59_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-08-17_16-12-59_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-04-22_19-05-14_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-07-18_16-47-42_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-07-16_22-23-10_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-01-18_19-54-10_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-03-02_15-19-08_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-02-17_17-48-56_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-01-15_00-10-38_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-04-14_16-12-08_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-10-21_16-41-29_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-05-19_13-38-32_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-02-07_12-57-09_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-12-15_11-57-14_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-02-14_21-13-21_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-07-08_21-13-47_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-01-26_16-41-19_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-11-14_14-13-55_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-11-29_17-27-08_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-09-27_10-32-52_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-07-16_20-16-22_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-03-11_18-41-20_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-04-19_14-26-28_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-03-26_19-16-32_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-09-07_22-10-38_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-04-25_11-05-59_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-11-22_18-50-09_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-06-16_16-58-54_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-06-15_15-31-25_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-09-04_18-16-21_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-06-29_11-46-37_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-01-03_20-29-30_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-11-19_18-44-55_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-02-07_18-31-40_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2019-10-28_16-47-32_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-07-05_11-59-24_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-03-03_19-05-50_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-10-15_01-15-46_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2019-10-30_20-59-33_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-11-17_15-26-00_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-05-01_01-14-53_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-06-17_19-08-58_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2019-12-21_19-56-59_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-05-08_01-47-22_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-01-09_17-08-48_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-06-10_19-01-17_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-04-13_13-51-19_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-10-19_18-07-11_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-05-14_19-32-55_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-04-13_17-51-03_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-01-10_10-20-53_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-10-20_19-39-30_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-01-29_15-10-48_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-05-05_17-09-53_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-07-08_19-24-14_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-05-21_17-29-34_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-02-11_18-20-57_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-06-17_18-41-55_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-04-01_19-48-16_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-04-14_20-21-47_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-06-17_18-11-13_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-02-06_14-39-19_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-04-26_16-59-15_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-06-28_10-27-44_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-10-22_17-44-30_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-01-09_16-56-39_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2019-11-21_17-06-39_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-06-20_21-40-56_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-11-18_19-19-23_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-02-01_13-36-17_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-05-28_12-31-58_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-01-06_16-23-56_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-06-11_22-25-37_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-02-22_14-13-49_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2019-10-28_19-47-24_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-10-06_21-18-33_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-02-07_21-37-35_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2019-10-15_22-49-43_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2019-12-27_18-57-44_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-10-20_19-21-36_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-02-03_22-15-05_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-01-28_20-24-04_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-02-21_18-30-32_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-01-05_23-40-33_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-04-26_23-40-44_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-02-22_17-37-40_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-05-24_19-21-45_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-03-03_18-27-58_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-10-03_17-59-45_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-03-20_11-54-11_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-01-23_12-26-00_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-03-06_23-32-17_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-12-02_16-41-01_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-12-03_12-20-40_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-04-21_18-52-28_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-02-12_17-01-18_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-04-27_15-01-22_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-10-14_13-47-32_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-09-24_16-56-00_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-06-20_13-58-11_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-02-19_15-39-05_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-06-08_15-33-43_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-04-19_17-35-43_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-01-07_10-09-19_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-08-07_13-17-46_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-12-13_08-47-50_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-02-22_13-41-38_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-06-30_20-14-34_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-06-28_16-00-44_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-09-26_18-39-50_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-07-20_15-15-09_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-05-03_17-25-34_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-06-15_15-09-25_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-01-28_14-50-58_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-04-11_14-24-18_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-04-04_14-52-18_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-03-14_10-34-16_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-02-06_20-38-41_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-04-07_13-09-57_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-08-20_10-35-18_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-08-14_11-22-36_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-01-15_19-49-19_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-12-13_17-26-17_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2019-10-16_17-01-47_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-09-28_12-50-56_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-05-27_19-57-20_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-03-14_15-27-44_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-01-20_13-53-32_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-08-31_12-47-02_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-05-09_20-22-37_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-03-26_02-53-30_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-04-26_18-31-58_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-10-03_20-05-15_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-04-18_23-52-15_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-04-10_19-53-23_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-05-02_13-36-36_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-09-25_22-25-25_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-09-15_16-52-51_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-04-21_18-36-08_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-10-14_14-59-59_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-03-23_21-32-44_UTC_2.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-09-27_12-51-30_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-01-11_16-31-08_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-03-08_16-28-29_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-05-22_20-11-22_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-11-16_19-25-13_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-07-05_13-58-26_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-12-16_00-53-18_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-03-06_13-15-24_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-01-05_21-12-54_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-03-29_17-03-56_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-12-05_11-56-56_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-12-12_12-38-46_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-01-20_20-24-12_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-07-27_13-41-52_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-06-25_13-19-35_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-07-14_22-49-43_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-01-02_14-37-51_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-10-30_10-39-20_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-09-04_19-03-30_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-07-08_18-00-12_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-10-21_15-33-44_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-01-11_13-02-13_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-04-13_23-20-12_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-01-20_15-00-41_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-01-24_15-51-25_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-06-28_20-54-44_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-01-17_13-46-38_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-02-13_20-23-15_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-06-17_15-33-52_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-02-06_09-43-29_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-02-06_16-04-59_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-06-13_16-02-09_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-02-18_18-03-15_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-09-18_10-58-17_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-07-13_16-48-43_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-05-01_17-58-24_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-01-12_13-43-29_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-04-28_19-33-11_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-10-31_19-47-30_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-04-20_20-27-38_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-01-02_10-48-35_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-04-28_15-20-20_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-06-17_18-08-01_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-06-09_20-56-36_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2019-10-16_18-06-32_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-03-11_12-15-12_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-07-26_18-04-49_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-07-16_13-31-24_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-01-22_21-14-24_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-09-03_17-42-18_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-07-17_12-38-09_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-09-05_23-32-10_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2019-12-06_12-15-22_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-05-05_22-05-22_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-12-12_22-20-58_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-03-03_14-02-16_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-02-12_14-16-41_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2019-11-18_18-16-36_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-10-09_18-59-38_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-07-02_14-07-15_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-06-02_20-35-42_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-03-17_15-19-44_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-01-07_13-58-50_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-02-05_13-13-18_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-11-20_10-39-59_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2019-10-04_18-26-42_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-04-06_20-20-54_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2019-12-28_11-01-51_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-04-16_16-43-11_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-12-04_20-40-28_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-11-25_17-07-00_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-08-27_17-11-43_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-07-31_22-51-56_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-07-06_12-50-45_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-03-08_16-51-21_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-12-08_20-48-11_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-07-30_16-47-19_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-01-09_22-45-31_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-05-21_17-12-14_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-01-21_22-01-02_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-10-25_14-39-59_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-06-27_15-37-09_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-02-16_10-25-46_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-11-09_02-11-57_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-12-07_11-23-24_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-11-03_16-37-01_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-03-13_13-07-52_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-04-25_17-57-35_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-02-20_21-00-41_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-10-08_13-59-00_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-03-21_11-15-13_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-11-19_21-36-41_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-05-28_15-07-03_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-10-11_16-28-02_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-06-24_17-52-19_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-06-17_15-18-32_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-05-11_17-30-13_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-06-25_16-28-37_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-05-06_19-11-49_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2019-10-27_20-14-14_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-05-14_18-13-50_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-02-08_21-29-27_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-07-29_18-03-33_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-12-03_13-04-02_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-02-03_20-11-48_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-05-06_15-57-57_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-02-17_12-30-26_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-12-22_14-03-37_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-03-06_21-32-46_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-05-25_15-23-59_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-06-22_19-15-43_UTC_6.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-06-03_16-03-42_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-12-02_12-07-54_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-07-03_17-57-58_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-10-23_17-19-39_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-12-13_10-43-52_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-12-24_16-20-11_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-06-01_23-22-07_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-05-26_12-37-27_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2019-11-06_20-31-45_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-03-14_16-46-21_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-06-15_19-55-09_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-02-03_13-10-25_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-02-19_12-10-28_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-01-20_22-10-44_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-04-08_15-01-50_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-06-22_16-14-36_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-02-10_14-51-17_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-04-19_19-09-57_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-12-23_02-16-44_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-09-23_11-50-54_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-06-25_11-42-08_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-09-06_12-29-09_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2019-11-24_11-11-28_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-04-23_11-54-48_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-09-05_16-02-59_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-02-13_21-34-07_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-03-14_20-07-46_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-04-13_10-33-11_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-11-22_20-35-53_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-02-15_14-13-36_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-12-31_19-09-50_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-10-22_00-15-24_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-01-20_22-11-42_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-01-31_21-20-47_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-03-22_14-54-36_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-03-19_12-12-28_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-06-17_18-56-52_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-06-18_10-58-58_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-04-18_00-13-33_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-03-10_17-06-07_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-08-05_18-11-17_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-05-17_16-37-57_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-08-13_22-01-38_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2019-10-17_09-58-30_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-06-12_12-17-28_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-03-15_15-27-03_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-07-08_17-46-29_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-01-27_11-17-21_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-12-29_00-36-36_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-03-16_19-08-15_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-04-03_22-59-41_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-11-30_00-22-04_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-01-09_17-30-15_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-05-06_14-48-16_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-10-25_18-00-01_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-07-14_19-55-28_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-03-22_22-14-49_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-11-02_21-19-22_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-08-05_22-55-25_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-09-06_23-20-59_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-01-16_21-40-45_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-03-28_14-15-28_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-09-17_21-59-11_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-11-20_15-25-53_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-11-28_12-58-51_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-11-08_11-30-15_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2019-10-23_22-26-15_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-01-14_20-44-30_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-06-06_15-39-46_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-07-24_16-30-36_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-04-28_17-45-22_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-06-24_12-30-26_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-02-24_03-48-10_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2019-12-03_13-05-45_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-08-23_12-58-04_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-04-26_13-08-08_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-02-13_16-07-53_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-02-27_14-10-48_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-03-02_18-23-58_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-03-26_22-17-36_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-07-08_15-01-57_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-11-24_15-42-21_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2019-11-20_19-51-56_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-07-15_19-48-24_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-04-18_12-38-20_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-01-31_23-15-37_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-07-25_08-14-26_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-05-27_20-55-08_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-03-09_07-38-44_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-01-07_14-25-31_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-08-13_20-06-39_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-06-23_10-55-47_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-03-16_13-39-04_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-12-17_21-23-16_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-09-26_16-31-08_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-02-20_14-08-07_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-07-19_02-18-47_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-09-22_18-05-42_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-06-13_17-01-52_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-02-08_18-22-54_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-05-02_06-52-21_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-12-30_16-42-40_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-07-25_19-05-50_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-04-09_23-10-04_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-02-14_14-45-19_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-04-09_14-34-23_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-10-20_19-19-49_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-10-07_18-19-52_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-03-03_02-01-13_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-04-29_21-30-17_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-08-02_19-29-19_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-02-12_16-03-10_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-09-17_15-12-26_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-07-15_18-44-25_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-03-28_18-43-04_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-03-30_19-58-52_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-11-19_21-36-54_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-02-18_21-44-29_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-08-19_15-33-18_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-02-09_10-03-40_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-04-08_09-56-41_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2019-11-22_17-40-07_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-01-31_17-42-01_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-08-26_18-27-46_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-09-19_10-49-44_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-02-12_11-20-09_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-04-26_20-01-14_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-02-05_14-57-04_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-05-06_17-14-34_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-04-25_16-08-11_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-07-30_22-36-49_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-03-24_13-31-44_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-08-05_10-27-00_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-04-26_14-16-46_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-03-05_15-33-14_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-01-24_15-49-25_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-10-23_12-37-53_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-04-30_11-58-13_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-05-07_23-11-11_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-07-13_17-52-02_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-09-13_21-44-42_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-03-04_20-01-02_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-03-20_22-07-37_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-01-06_21-36-10_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-02-05_12-06-53_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-04-24_01-26-35_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-12-03_14-35-57_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-06-03_16-06-11_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-05-16_18-32-33_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-10-08_19-23-18_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-03-21_15-20-16_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-01-25_12-42-58_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-03-17_20-41-36_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-06-03_09-55-56_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-11-07_17-34-05_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-02-18_20-33-31_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-11-28_14-35-10_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-08-30_14-59-44_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2023-02-09_16-49-39_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-11-28_18-11-05_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-01-17_16-42-00_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-11-04_16-14-10_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-04-16_00-35-24_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-06-17_13-07-36_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2019-10-23_14-41-34_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-05-07_00-35-26_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2020-07-25_15-04-06_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-04-05_10-57-20_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2022-08-09_12-57-40_UTC.jpg
# data/arabic_memes_fb_insta_pinterest/Instagram/IMAGES/ex.officiall/2021-10-28_20-56-40_UTC.jpg
# ...
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_899031144344763392/e762d4d355f9d9db721c2962f8bbadc5.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_899031144344763392/b7533c9d7c48f54317eaf8dc06539fe7.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_899031144344763392/499fc5703065586d204a9441e4df2eea.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_899031144344763392/df47aa37e77942543c72b6bbf206cbe3.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_899031144344763392/068a4865772462e714a57c070687166d.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_899031144344763392/47d8269fa35fb85c9b08d166a5eeb149.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_899031144344763392/047b66579f8fba73558325d614b8bbbf.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_899031144344763392/1e5ff1e547bd305ea7ad96303a8a98a6.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_899031144344763392/88b93bce4d5050d5a269c2105dd2e4ea.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_899031144344763392/ae42ce443a27a895151353f536929d37.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_374924737744527609/3ee3ed7629546d1dbc5f494160e6c283.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_374924737744527609/d59a82270166f34852827416e950e3bc.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_374924737744527609/4b1bff7e35f67726f418d80cdf3c3069.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_374924737744527609/4474e610084ca759f7463e032e27ef0d.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_374924737744527609/6fc16c5a52a1a95ec40a0fd3b7396362.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_374924737744527609/950e98fa96b571317a751b910730cd90.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_374924737744527609/2f173d496ff6b93f7a3eff8a63eaa776.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_374924737744527609/818b45457f712c5fe5707de5dabe2719.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_578853358376880423/f8d2bb5ae4ec3c1203c3b51e8327d710.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_578853358376880423/4f7e2304d4fd7bfd8267118c3eccf47c.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_578853358376880423/27756cd9c0b96a7211fdb4bc0f6b8d86.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_578853358376880423/9573b0067c8f222d2574c6072918c069.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_578853358376880423/bcbd5f2828dc11e699845592b2147a38.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_578853358376880423/f3ab5f824e3ef84ef48d901d157d112a.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_578853358376880423/76023f19915d3a005e989a18bfd5ae88.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_578853358376880423/831e3a0d6c703cdf70138116d0bcb01d.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_578853358376880423/2969394f1b7ce4c9cef15cac99441f5c.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_578853358376880423/81bd6fcb6040fea886b0dbe27c5c40e7.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_578853358376880423/3312d32d301d0eff7ee68b85ab54e181.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_578853358376880423/a584f41cb95c8081ef71cf221e8bad6c.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_578853358376880423/f671a22a3b04335a4a2697b88eab244e.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_578853358376880423/e07edb105a38f6f73695430dd95b5db7.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_578853358376880423/210ea3b01687490fc359b6aa85bff018.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_578853358376880423/8c0abfcdc821a5a0f6130282f73ef002.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_578853358376880423/d706fefb8c94a73dfc99c4f9bcde2fd9.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/efeaf34aff346aea8e61084b5872556c.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/bec9604864c6cfd2620ba6af607ea851.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/be6c51e6805c85425c2089085edbe3e5.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/1fcad72dad45b72057e4d33baa1eb258.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/828127b60a26ded2c9de39059543d9fc.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/f4b180e7036219ad6a7c8897b5790f9b.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/b87ae474136d99ab40ad03c9e07b4efd.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/629ac9618f962bfbdf8cdb2529088b45.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/5e0d6c5f383e8eac89b9c5c542b3b2c1.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/a20cc917d9f7ff70f12cb888daa4de95.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/5d0045edc7c7c29adeb5b64362d8d546.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/176478968249d98770102ea6e58cebd0.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/0f2c6e0dfa4c168769e803a58ca948e5.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/bf343e2b46065f9524ef882d4a3fffdd.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/8506e774f529e58af45f5091c7c7ba97.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/fd8baebdaae5173bd7b5423021c35565.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/3a2d1ea327fc10f801fc2468ff91612c.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/d35e3828fad7b6855515234c0576611b.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/c3bf5a022aa2cbdfe96c97627605c14a.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/b291319f7419abdb8bcdd4b1bce64802.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/cba99ef032474e379123b6076b3e3649.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/f72201ac411cad069f2fceee3d39d5a7.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/2ecef715d849003c83b5fece8062740b.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/1035e0513d6c9a9542b75a95f9148b75.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/6984f9bde4a682700ec693ce108f596d.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/c310def8dd859668d80a0dcaf69039d1.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/a72586c0aaeac29f53b382af9fde5d5c.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/4f8bce9a2e26ddd4e39c3befa03954a4.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/d291786d6941da80d08313c3e074853a.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/af938d4e8c89447388b8c9c93e2f264d.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/6e8672df04846cbcdc8180132160ca2e.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/e8a709844a4fae4b36ef49792fbc1614.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/c84fb6239934a8640b944aa3fe20456e.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_384283780715921583/02717d22b608a437fec769cf16761feb.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_115264071700638504/8c10023865b43cf5a05a0c5f0b41709a.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_115264071700638504/52a6021545ea368d9471d0f63cb2b563.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_115264071700638504/ac5db72812205b593a28ddf1af48f995.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_115264071700638504/5d69cf7d63f7e5579da2c39507d64d7f.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_115264071700638504/06184594444e29f545e635df571b0815.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_115264071700638504/77cad368dbfda977ac5144f82476b7cf.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_115264071700638504/6a1d82bf96df5ed1ae55c8f9d2b2ba44.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_115264071700638504/d40df47acfa87455281d57ed5612e736.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_115264071700638504/ad27c808238c6bcd4c10babb52c95673.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_115264071700638504/4a92a2d285f2bfd8849839d9763612e0.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_115264071700638504/87f4057c3367a652c4fa8ac0fd5b1991.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_115264071700638504/e828dc96c3b91b1bab5a354659ce6ce5.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_115264071700638504/ae83cc93be1259ac2a8bb7472b3c6242.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_115264071700638504/dd9de94c6c73faee6c3db53aafd6c854.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_115264071700638504/473926026d533b22be8439a744e864ed.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_115264071700638504/92d8453ce2e50b520b8e9076cdbb6bb9.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_115264071700638504/dffe291428cfb36b0b847ffe4440a9a4.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_115264071700638504/efd9284bdf604d080276f27855c97d50.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_115264071700638504/71e7a87efc9ea91b0d3502d606db1a91.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_115264071700638504/2da81030882c8559101f9b1383aacf72.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_115264071700638504/1a8f25603103e16e62c61a29560689f3.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_115264071700638504/feedda3f662021d9231050b6d3b09fcb.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_115264071700638504/4e74815378aa7e570e9b6c9e7a43bf6e.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_115264071700638504/3d3b693f33fc90014a7d6624463c9f89.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_115264071700638504/049c72d1af961caa6a669f2e68045ea4.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_115264071700638504/eb6e8a2faf82dc48ee830587496d26f5.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_115264071700638504/1f3579f16f751de2450baf870a792b73.jpg
# data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_115264071700638504/fcf1534073ed89a3437915435ab72ae3.jpg
# data/images/twitter/
# data/images/twitter/8_11_2018/
# data/images/twitter/7_6_2016/
# data/images/twitter/5_9_2015/
# data/images/twitter/13_1_2015/
# data/images/twitter/2_5_2012/
# data/images/twitter/31_5_2015/
# data/images/twitter/22_12_2014/
# data/images/twitter/22_12_2014/547146688423411712_0.jpg
# data/images/twitter/31_5_2015/605124471326932994_0.jpg
# data/images/twitter/2_5_2012/197818830720995328_0.jpg
# data/images/twitter/13_1_2015/555104009191964673_0.jpg
# data/images/twitter/5_9_2015/640292760944140288_0.jpg
# data/images/twitter/7_6_2016/740272362000646144_0.jpg
# data/images/twitter/8_11_2018/1060643580837007360_2.jpg

# %% [markdown]
# ### installing required libraries.
#  - transformers
#  - datasets
#  - evaluate
#  - accelerate

# %%
# !pip install transformers
# !pip install datasets
# !pip install evaluate
# !pip install --upgrade accelerate
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.38.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Collecting datasets
#   Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 8.4 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->datasets) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, dill, multiprocess, datasets
# Successfully installed datasets-2.18.0 dill-0.3.8 multiprocess-0.70.16 xxhash-3.4.1
# Collecting evaluate
#   Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.25.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from evaluate) (4.66.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2023.6.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (24.0)
# Collecting responses<0.19 (from evaluate)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.13.1)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (0.6)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.9.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2023.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->evaluate) (1.16.0)
# Installing collected packages: responses, evaluate
# Successfully installed evaluate-0.4.1 responses-0.18.0
# Collecting accelerate
#   Downloading accelerate-0.28.0-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.2.1+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 32.2 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 51.1 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 58.9 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.1 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.0 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.5 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.9 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 5.5 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.5 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 6.1 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 48.8 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, accelerate
# Successfully installed accelerate-0.28.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105

# %% [markdown]
# #### importing required libraries and setting up logger

# %%
import logging
import os
import random
import sys
from dataclasses import dataclass, field
from typing import Optional
import pandas as pd
import datasets
import evaluate
import numpy as np
from torchvision.transforms import Compose, Normalize, ToTensor, Resize, CenterCrop
from datasets import load_dataset, Dataset, DatasetDict
import torch

import transformers
from transformers import (
    ConvNextFeatureExtractor,
    ResNetConfig,
    ResNetForImageClassification,
    DataCollatorWithPadding,
    EvalPrediction,
    HfArgumentParser,
    PretrainedConfig,
    Trainer,
    TrainingArguments,
    default_data_collator,
    set_seed,
)
from transformers.trainer_utils import get_last_checkpoint
from transformers.utils import check_min_version, send_example_telemetry
from transformers.utils.versions import require_version


logger = logging.getLogger(__name__)

logging.basicConfig(
    format="%(asctime)s - %(levelname)s - %(name)s - %(message)s",
    datefmt="%m/%d/%Y %H:%M:%S",
    handlers=[logging.StreamHandler(sys.stdout)],
)

# %% [markdown]
# ### Defining the training, validation, and test data

# %%
train_file = 'arabic_memes_propaganda_araieval_24_train.json'
validation_file = 'arabic_memes_propaganda_araieval_24_dev.json'
# test_file = 'arabic_memes_propaganda_araieval_24_test.json'

# %% [markdown]
# ### Setting up the training parameters

# %%
training_args = TrainingArguments(
    learning_rate=2e-5,
    num_train_epochs=2,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    output_dir="./resnet_50/",
    overwrite_output_dir=True,
    remove_unused_columns=False,
    local_rank= 1,
    load_best_model_at_end=True,
    save_total_limit=2,
    save_strategy="no"
)

max_train_samples = None
max_eval_samples=None
max_predict_samples=None
batch_size = 16

# %%
transformers.utils.logging.set_verbosity_info()

log_level = training_args.get_process_log_level()
logger.setLevel(log_level)
datasets.utils.logging.set_verbosity(log_level)
transformers.utils.logging.set_verbosity(log_level)
transformers.utils.logging.enable_default_handler()
transformers.utils.logging.enable_explicit_format()
logger.warning(
    f"Process rank: {training_args.local_rank}, device: {training_args.device}, n_gpu: {training_args.n_gpu}"
    + f" distributed training: {bool(training_args.local_rank != -1)}, 16-bits training: {training_args.fp16}"
)
logger.info(f"Training/evaluation parameters {training_args}")
# Out:
# WARNING:__main__:Process rank: 0, device: cpu, n_gpu: 0 distributed training: True, 16-bits training: False
# INFO:__main__:Training/evaluation parameters TrainingArguments(
# _n_gpu=0,
# accelerator_config={'split_batches': False, 'dispatch_batches': None, 'even_batches': True, 'use_seedable_sampler': True},
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_persistent_workers=False,
# dataloader_pin_memory=True,
# dataloader_prefetch_factor=None,
# ddp_backend=None,
# ddp_broadcast_buffers=None,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# dispatch_batches=None,
# do_eval=False,
# do_predict=False,
# do_train=False,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_steps=None,
# evaluation_strategy=no,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# fsdp=[],
# fsdp_config={'min_num_params': 0, 'xla': False, 'xla_fsdp_v2': False, 'xla_fsdp_grad_ckpt': False},
# fsdp_min_num_params=0,
# fsdp_transformer_layer_cls_to_wrap=None,
# full_determinism=False,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# gradient_checkpointing_kwargs=None,
# greater_is_better=False,
# group_by_length=False,
# half_precision_backend=auto,
# hub_always_push=False,
# hub_model_id=None,
# hub_private_repo=False,
# hub_strategy=every_save,
# hub_token=<HUB_TOKEN>,
# ignore_data_skip=False,
# include_inputs_for_metrics=False,
# include_num_input_tokens_seen=False,
# include_tokens_per_second=False,
# jit_mode_eval=False,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=2e-05,
# length_column_name=length,
# load_best_model_at_end=True,
# local_rank=0,
# log_level=passive,
# log_level_replica=warning,
# log_on_each_node=True,
# logging_dir=./resnet_50/runs/Mar22_06-10-38_e85def998272,
# logging_first_step=False,
# logging_nan_inf_filter=True,
# logging_steps=500,
# logging_strategy=steps,
# lr_scheduler_kwargs={},
# lr_scheduler_type=linear,
# max_grad_norm=1.0,
# max_steps=-1,
# metric_for_best_model=loss,
# mp_parameters=,
# neftune_noise_alpha=None,
# no_cuda=False,
# num_train_epochs=2,
# optim=adamw_torch,
# optim_args=None,
# output_dir=./resnet_50/,
# overwrite_output_dir=True,
# past_index=-1,
# per_device_eval_batch_size=16,
# per_device_train_batch_size=16,
# prediction_loss_only=False,
# push_to_hub=False,
# push_to_hub_model_id=None,
# push_to_hub_organization=None,
# push_to_hub_token=<PUSH_TO_HUB_TOKEN>,
# ray_scope=last,
# remove_unused_columns=False,
# report_to=['tensorboard'],
# resume_from_checkpoint=None,
# run_name=./resnet_50/,
# save_on_each_node=False,
# save_only_model=False,
# save_safetensors=True,
# save_steps=500,
# save_strategy=no,
# save_total_limit=2,
# seed=42,
# skip_memory_metrics=True,
# split_batches=None,
# tf32=None,
# torch_compile=False,
# torch_compile_backend=None,
# torch_compile_mode=None,
# torchdynamo=None,
# tpu_metrics_debug=False,
# tpu_num_cores=None,
# use_cpu=False,
# use_ipex=False,
# use_legacy_prediction_loop=False,
# use_mps_device=False,
# warmup_ratio=0.0,
# warmup_steps=0,
# weight_decay=0.0,
# )

# %% [markdown]
# #### Defining the Model

# %%
model_name = 'resnet50'

# %% [markdown]
# #### setting the random seed

# %%
set_seed(training_args.seed)

# %% [markdown]
# #### Loading data files

# %%
import json
#from PIL import Image
import PIL
from datasets import Image
from tqdm import tqdm

# Image.open(obj['img_path']).convert("RGB")

def read_data(fpath, is_test=False):
  if is_test:
    data = {'id': [], 'image': []}
    js_obj = json.load(open(fpath, encoding='utf-8'))
    for obj in tqdm(js_obj):
      data['id'].append(obj['id'])
      data['image'].append(obj['img_path'])
  else:
    data = {'id': [], 'image': [], 'label': []}
    js_obj = json.load(open(fpath, encoding='utf-8'))
    for obj in tqdm(js_obj):
      data['id'].append(obj['id'])
      data['image'].append(obj['img_path'])
      data['label'].append(obj['class_label'])
  return pd.DataFrame.from_dict(data)


l2id = {'not_propaganda': 0, 'propaganda': 1}
train_df = read_data(train_file)
train_df['label'] = train_df['label'].map(l2id)
train_df = Dataset.from_pandas(train_df).cast_column("image", Image())
validation_df = read_data(validation_file)
validation_df['label'] = validation_df['label'].map(l2id)
validation_df = Dataset.from_pandas(validation_df).cast_column("image", Image())
# test_df = read_data(test_file)
# #test_df['label'] = test_df['label'].map(l2id)
# test_df = Dataset.from_pandas(test_df).cast_column("image", Image())



#data_files = {"train": train_df, "validation": validation_df, "test": validation_df}
data_files = {"train": train_df, "validation": validation_df}
for key in data_files.keys():
    logger.info(f"loading a local file for {key}")
raw_datasets = DatasetDict(
    {"train": train_df, "validation": validation_df} # , "test": test_df
)
# Out:
# 100%|██████████| 2143/2143 [00:00<00:00, 485859.11it/s]
# 100%|██████████| 312/312 [00:00<00:00, 234100.69it/s]
# INFO:__main__:loading a local file for train
# INFO:__main__:loading a local file for validation

# %% [markdown]
# ##### Extracting number of unique labels

# %%
# Labels
label_list = raw_datasets["train"].unique("label")
label_list.sort()  # sort the labels for determine
num_labels = len(label_list)

# %% [markdown]
# ### Loading Pretrained Configuration, Tokenizer and Model

# %%
config = ResNetConfig(
        num_channels=1,
        layer_type="basic",
        depths=[2, 2],
        hidden_sizes=[32, 64],
        num_labels=num_labels,
)

model = ResNetForImageClassification(config)

# %% [markdown]
# #### Preprocessing the raw_datasets

# %%
feature_extractor = ConvNextFeatureExtractor(
    do_resize=True, do_normalize=False, image_mean=[0.45], image_std=[0.22]
)
normalize = Normalize(mean=feature_extractor.image_mean, std=feature_extractor.image_std)
_transforms = Compose([Resize(256), CenterCrop(224), ToTensor(), normalize])

def transforms(example_batch):
    """Apply _train_transforms across a batch."""
    # print(example_batch)
    # black and white
    example_batch["pixel_values"] = [_transforms(pil_img.convert("L")) for pil_img in example_batch["image"]]
    return example_batch
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/convnext/feature_extraction_convnext.py:28: FutureWarning: The class ConvNextFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ConvNextImageProcessor instead.
#   warnings.warn(

# %% [markdown]
# #### Finalize the training data for training the model

# %%
if "train" not in raw_datasets:
    raise ValueError("requires a train dataset")
train_dataset = raw_datasets["train"]
if max_train_samples is not None:
    max_train_samples_n = min(len(train_dataset), max_train_samples)
    train_dataset = train_dataset.select(range(max_train_samples_n))
train_dataset.set_transform(transforms)

# %%
train_dataset
# Out:
# Dataset({
#     features: ['id', 'image', 'label'],
#     num_rows: 2143
# })

# %% [markdown]
# #### Finalize the development/evaluation data for evaluating the model

# %%
if "validation" not in raw_datasets:
    raise ValueError("requires a validation dataset")
eval_dataset = raw_datasets["validation"]
if max_eval_samples is not None:
    max_eval_samples_n = min(len(eval_dataset), max_eval_samples)
    eval_dataset = eval_dataset.select(range(max_eval_samples_n))
eval_dataset.set_transform(transforms)

# %% [markdown]
# #### Finalize the test data for predicting the unseen test data using the model

# %%
if "test" not in raw_datasets and "test_matched" not in raw_datasets:
    raise ValueError("requires a test dataset")
predict_dataset = raw_datasets["test"]
if max_predict_samples is not None:
    max_predict_samples_n = min(len(predict_dataset), max_predict_samples)
    predict_dataset = predict_dataset.select(range(max_predict_samples_n))
predict_dataset = predict_dataset.set_transform(transforms)

# %% [markdown]
# #### Log a few random samples from the training set

# %%
for index in random.sample(range(len(train_dataset)), 3):
    logger.info(f"Sample {index} of the training set: {train_dataset[index]}.")
# Out:
# INFO:__main__:Sample 456 of the training set: {'id': 'data/arabic_memes_fb_insta_pinterest/Facebook/images/sanat.meme_/79517291_1444731972385670_3984977326792453161_n.jpg', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=526x832 at 0x7E845758ED70>, 'label': 1, 'pixel_values': tensor([[[ 0.0579,  0.5927,  0.0045,  ..., -1.3146, -1.2255, -1.2077],
#          [-0.1203, -0.1916, -0.2451,  ..., -1.4929, -1.2255, -1.1720],
#          [-0.4590, -0.4590, -0.1381,  ..., -1.2968, -1.3859, -1.2611],
#          ...,
#          [ 0.0401, -0.3520, -0.5303,  ..., -0.9581, -0.9581, -0.9759],
#          [ 0.0936, -0.3699, -0.6016,  ..., -0.9938, -0.9938, -0.9938],
#          [ 0.2184, -0.2094, -0.5660,  ..., -1.0116, -1.0116, -0.9938]]])}.
# INFO:__main__:Sample 102 of the training set: {'id': 'data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_864409722250727930/4e94ecf08d54e8922e9f8fc0bcdee1cf.jpg', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=549x666 at 0x7E831AD34CA0>, 'label': 1, 'pixel_values': tensor([[[ 0.3075,  0.3075, -0.0312,  ...,  2.5000,  2.5000,  2.5000],
#          [ 0.1649,  0.2362,  0.2362,  ...,  2.5000,  2.5000,  2.5000],
#          [-0.1381,  0.2362,  0.5036,  ...,  2.5000,  2.5000,  2.5000],
#          ...,
#          [ 2.1791,  1.8939,  1.3592,  ...,  2.4643,  2.4643,  2.4643],
#          [ 2.1970,  2.1078,  1.6800,  ...,  2.5000,  2.5000,  2.5000],
#          [ 2.1970,  2.1078,  1.9296,  ...,  2.5000,  2.5000,  2.5000]]])}.
# INFO:__main__:Sample 1126 of the training set: {'id': 'data/arabic_memes_fb_insta_pinterest/Pinterest/images/pinterest_image_august13/www.pinterest.com_pin_126241595793002111/36ad37edee11b6313b841210f8a518f1.jpg', 'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=564x933 at 0x7E831AD34D00>, 'label': 0, 'pixel_values': tensor([[[ 1.8583,  1.0205, -1.5285,  ...,  0.4501, -1.2255,  1.4661],
#          [ 1.7335,  1.1809, -1.4394,  ...,  0.2362, -1.2968,  1.3770],
#          [ 1.3948,  1.1988, -1.4394,  ..., -0.3520, -1.3146,  1.2879],
#          ...,
#          [-0.2629,  0.0223, -0.9403,  ..., -1.8494, -1.8316, -1.7959],
#          [-0.6194, -0.0134, -0.6551,  ..., -1.7781, -1.7602, -1.7068],
#          [-0.8868, -0.7264, -1.0829,  ..., -1.7246, -1.7068, -1.6355]]])}.

# %% [markdown]
# #### Get the metric function `accuracy`

# %%
metric = evaluate.load("accuracy")
# Out:
# Downloading builder script:   0%|          | 0.00/4.20k [00:00<?, ?B/s]

# %% [markdown]
# #### Predictions and label_ids field and has to return a dictionary string to float.

# %%
def compute_metrics(p: EvalPrediction):
    preds = p.predictions[0] if isinstance(p.predictions, tuple) else p.predictions
    preds = np.argmax(preds, axis=1)
    return {"accuracy": (preds == p.label_ids).astype(np.float32).mean().item()}

# %% [markdown]
# #### Data Collator

# %%
def collate_fn(examples):
    # print(examples)
    pixel_values = torch.stack([example["pixel_values"] for example in examples])
    labels = torch.tensor([example["label"] for example in examples])
    return {"pixel_values": pixel_values, "labels": labels}
data_collator = collate_fn

# %% [markdown]
# #### Initialize our Trainer

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    # eval_dataset=eval_dataset, # if you have development and test set, uncomment this line
    compute_metrics=compute_metrics,
    tokenizer=feature_extractor,
    data_collator=data_collator,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:432: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(

# %% [markdown]
# #### Training our model

# %%
train_result = trainer.train()
metrics = train_result.metrics
max_train_samples = (
    max_train_samples if max_train_samples is not None else len(train_dataset)
)
metrics["train_samples"] = min(max_train_samples, len(train_dataset))
# Out:
# [INFO|trainer.py:1812] 2024-03-22 06:11:21,047 >> ***** Running training *****
# [INFO|trainer.py:1813] 2024-03-22 06:11:21,048 >>   Num examples = 2,143
# [INFO|trainer.py:1814] 2024-03-22 06:11:21,053 >>   Num Epochs = 2
# [INFO|trainer.py:1815] 2024-03-22 06:11:21,055 >>   Instantaneous batch size per device = 16
# [INFO|trainer.py:1818] 2024-03-22 06:11:21,058 >>   Total train batch size (w. parallel, distributed & accumulation) = 16
# [INFO|trainer.py:1819] 2024-03-22 06:11:21,059 >>   Gradient Accumulation steps = 1
# [INFO|trainer.py:1820] 2024-03-22 06:11:21,061 >>   Total optimization steps = 268
# [INFO|trainer.py:1821] 2024-03-22 06:11:21,063 >>   Number of trainable parameters = 183,554
#     <div>
#
#       <progress value='268' max='268' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [268/268 08:45, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# [INFO|trainer.py:2067] 2024-03-22 06:20:09,039 >>
#
# Training completed. Do not forget to share your model on huggingface.co/models =)

# %% [markdown]
# #### Saving the tokenizer too for easy upload

# %%
trainer.save_model()
trainer.log_metrics("train", metrics)
trainer.save_metrics("train", metrics)
trainer.save_state()
# Out:
# [INFO|trainer.py:3067] 2024-03-22 06:20:09,069 >> Saving model checkpoint to ./resnet_50/
# [INFO|configuration_utils.py:473] 2024-03-22 06:20:09,077 >> Configuration saved in ./resnet_50/config.json
# [INFO|modeling_utils.py:2454] 2024-03-22 06:20:09,089 >> Model weights saved in ./resnet_50/model.safetensors
# [INFO|image_processing_utils.py:257] 2024-03-22 06:20:09,092 >> Image processor saved in ./resnet_50/preprocessor_config.json
# ***** train metrics *****
#   epoch                    =        2.0
#   total_flos               =   220578GF
#   train_loss               =     0.6074
#   train_runtime            = 0:08:47.97
#   train_samples            =       2143
#   train_samples_per_second =      8.118
#   train_steps_per_second   =      0.508

# %% [markdown]
# #### Evaluating our model on validation/development data

# %%
logger.info("*** Evaluate ***")

metrics = trainer.evaluate(eval_dataset=eval_dataset)

max_eval_samples = (
    max_eval_samples if max_eval_samples is not None else len(eval_dataset)
)
metrics["eval_samples"] = min(max_eval_samples, len(eval_dataset))

trainer.log_metrics("eval", metrics)
trainer.save_metrics("eval", metrics)
# Out:
# INFO:__main__:*** Evaluate ***
# [INFO|trainer.py:3376] 2024-03-22 06:20:09,119 >> ***** Running Evaluation *****
# [INFO|trainer.py:3378] 2024-03-22 06:20:09,123 >>   Num examples = 312
# [INFO|trainer.py:3381] 2024-03-22 06:20:09,126 >>   Batch size = 16
#     <div>
#
#       <progress value='20' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20/20 00:13]
#     </div>
# ***** eval metrics *****
#   epoch                   =        2.0
#   eval_accuracy           =     0.7083
#   eval_loss               =     0.5812
#   eval_runtime            = 0:00:14.76
#   eval_samples            =        312
#   eval_samples_per_second =     21.131
#   eval_steps_per_second   =      1.355

# %% [markdown]
# ### Predecting the test data

# %%
# if the test set is available, you don't need to run this cell
predict_dataset = eval_dataset
predict_dataset
# Out:
# Dataset({
#     features: ['id', 'image', 'label'],
#     num_rows: 312
# })

# %%
id2l = {0:'not_propaganda', 1:'propaganda'}
logger.info("*** Predict ***")
#predict_dataset = predict_dataset.remove_columns("label")
#ids = predict_dataset['id']
#image = predict_dataset['image']
#predict_dataset = predict_dataset.remove_columns("id")
predictions = trainer.predict(predict_dataset, metric_key_prefix="predict").predictions
predictions = np.argmax(predictions, axis=1)
output_predict_file = os.path.join(training_args.output_dir, f"task2B_TeamName.tsv")
if trainer.is_world_process_zero():
    with open(output_predict_file, "w") as writer:
        logger.info(f"***** Predict results *****")
        writer.write("id\tlabel\trun_id\n")
        for index, item in enumerate(predictions):
            item = label_list[item]
            item = id2l[item]
            writer.write(f"{predict_dataset[index]['id']}\t{item}\t{model_name}\n")
# Out:
# INFO:__main__:*** Predict ***
# [INFO|trainer.py:3376] 2024-03-22 06:20:23,925 >> ***** Running Prediction *****
# [INFO|trainer.py:3378] 2024-03-22 06:20:23,927 >>   Num examples = 312
# [INFO|trainer.py:3381] 2024-03-22 06:20:23,931 >>   Batch size = 16
# INFO:__main__:***** Predict results *****

# %% [markdown]
# #### Saving the model into card

# %%
kwargs = {"finetuned_from": model_name, "tasks": "text-classification"}
trainer.create_model_card(**kwargs)
# Out:
# [INFO|modelcard.py:450] 2024-03-20 05:28:44,933 >> Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Text Classification', 'type': 'text-classification'}, 'metrics': [{'name': 'Accuracy', 'type': 'accuracy', 'value': 0.7916666865348816}]}
